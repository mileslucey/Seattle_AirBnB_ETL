# %%
# dependencies and setup
import pandas as pd
from sqlalchemy import create_engine

# %%
# Store CSV to DataFrame
listing_host_csv = "Resources/listings.csv"
listing_host_df = pd.read_csv(listing_host_csv,encoding="utf8")

# %%
# change column "name" to something that SQL doesn't already recognize
listing_host_df.rename(index=str,columns={"name":"listing_name"},inplace=True)
listing_host_df.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                           listing_name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                NaN
# 4  Cozy family craftman house in beautiful neighb...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
# 2  New modern house built in 2013.  Spectacular s...                none
# 3  A charming apartment that sits atop Queen Anne...                none
# 4  Cozy family craftman house in beautiful neighb...                none
#
#                                neighborhood_overview        ...         \
# 0                                                NaN        ...
# 1  Queen Anne is a wonderful, truly functional vi...        ...
# 2  Upper Queen Anne is a charming neighborhood fu...        ...
# 3                                                NaN        ...
# 4  We are in the beautiful neighborhood of Queen ...        ...
#
#   review_scores_value requires_license license jurisdiction_names  \
# 0                10.0                f     NaN         WASHINGTON
# 1                10.0                f     NaN         WASHINGTON
# 2                10.0                f     NaN         WASHINGTON
# 3                 NaN                f     NaN         WASHINGTON
# 4                 9.0                f     NaN         WASHINGTON
#
#   instant_bookable cancellation_policy  require_guest_profile_picture  \
# 0                f            moderate                              f
# 1                f              strict                              t
# 2                f              strict                              f
# 3                f            flexible                              f
# 4                f              strict                              f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              2
# 1                                t                              6
# 2                                f                              2
# 3                                f                              1
# 4                                f                              1
#
#   reviews_per_month
# 0              4.07
# 1              1.48
# 2              1.15
# 3               NaN
# 4              0.89
#
# [5 rows x 92 columns]

# %% [markdown]
# ### Creating the "Listings" dataframe and cleaning it

# %%
# Create new data with select columns for the AirBnB listings
listing_df = listing_host_df[["id","listing_name","street","neighbourhood_cleansed","neighbourhood_group_cleansed","city","state","zipcode","latitude","longitude","is_location_exact","property_type","room_type","accommodates","bathrooms","bedrooms","beds","bed_type","square_feet","price","weekly_price","monthly_price","security_deposit","cleaning_fee","guests_included","extra_people","minimum_nights","maximum_nights","has_availability","availability_30","availability_60","availability_90","availability_365","number_of_reviews","first_review","last_review","review_scores_rating","review_scores_accuracy","review_scores_cleanliness","review_scores_checkin","review_scores_communication","review_scores_location","review_scores_value","requires_license","instant_bookable","cancellation_policy","require_guest_profile_picture","require_guest_phone_verification","reviews_per_month","host_id"]].copy()

# %%
# convert dates to datetime
listing_df["first_review"]=pd.to_datetime(listing_df["first_review"])
listing_df["last_review"]=pd.to_datetime(listing_df["last_review"])

# %%
# convert boolean columns to boolean
listing_df["is_location_exact"].replace(["t","f"],[True,False],inplace=True)
listing_df["has_availability"].replace(["t","f"],[True,False],inplace=True)
listing_df["requires_license"].replace(["t","f"],[True,False],inplace=True)
listing_df["instant_bookable"].replace(["t","f"],[True,False],inplace=True)
listing_df["require_guest_profile_picture"].replace(["t","f"],[True,False],inplace=True)
listing_df["require_guest_phone_verification"].replace(["t","f"],[True,False],inplace=True)

# %%
# convert all the currency columns to numeric values instead of strings
# define the currency columns
currency_cols=["price","weekly_price","monthly_price","security_deposit","cleaning_fee","extra_people"]
# remove dollar sign and commas
listing_df[currency_cols]=listing_df[currency_cols].replace({'\$': '', ',': ''}, regex=True)
# changing the leftover value (minus currency sign and commas) to a number
listing_df["price"] = pd.to_numeric(listing_df["price"])
listing_df["weekly_price"] = pd.to_numeric(listing_df["weekly_price"])
listing_df["monthly_price"] = pd.to_numeric(listing_df["monthly_price"])
listing_df["security_deposit"] = pd.to_numeric(listing_df["security_deposit"])
listing_df["cleaning_fee"] = pd.to_numeric(listing_df["cleaning_fee"])
listing_df["extra_people"] = pd.to_numeric(listing_df["extra_people"])
listing_df
# Out:
#             id                         listing_name  \
# 0       241032         Stylish Queen Anne Apartment
# 1       953595   Bright & Airy Queen Anne Apartment
# 2      3308979  New Modern House-Amazing water view
# 3      7421966                   Queen Anne Chateau
# 4       278830       Charming craftsman 3 bdm house
# 5      5956968      Private unit in a 1920s mansion
# 6      1909058      Queen Anne Private Bed and Bath
# 7       856550    Tiny Garden cabin on Queen Anne
# 8      4948745     Urban Charm || Downtown || Views
# 9      2493658   Airy + Bright Queen Anne Apartment
# 10      175576  Private Apartment - Queen Anne Hill
# 11     4454295     Upper Queen Anne Craftsman House
# 12     3883392   Open Plan 2bdr/1bath in Queen Anne
# 13     8889257      Elegance in Historic Queen Anne
# 14     5680462  Stunning 6 bd in THE BEST Location!
# 15     8988178      Lovely Queen Anne Cottage, 2 BR
# 16     3245876        Park Life in Lower Queen Anne
# 17     4933447       Private Garden Suite, Bay View
# 18     7735464     Queen Anne Getaway Near Seattle!
# 19     6291829   Grand Craftsman Home on Queen Anne
# 20     9218403          Queen Anne View One Bedroom
# 21     4125779    Cozy Queen Anne Finished Basement
# 22     8942678               Lovely Queen Anne home
# 23    10106055   Cozy Lower Level, Upper Queen Anne
# 24     6362362          Charming home on Queen Anne
# 25     3544550        VIEW-Monthly Rental Available
# 26     9025039   Cute Bungalow-Close to Everything!
# 27     3200646      Micro Gypsy Wagon on Queen Anne
# 28     8859380         STUNNING VIEW of Puget Sound
# 29     4520099           Open Airy Queen Anne Condo
# ...        ...                                  ...
# 3788   7745196     Cozy Modern Apartment in Fremont
# 3789   4645405      Private light, minimalist room
# 3790   2755730   Your own 2 Bedroom home in Fremont
# 3791   7949448     Private Suite in Fremont-Ballard
# 3792   9288840                           City Haven
# 3793   3312406   Seattle Urban-Chic Studio Cottage
# 3794   6621924                Hazel Heights Hideout
# 3795   5673552   Beautiful loft in downtown Fremont
# 3796    609701      Charming Fremont Garden Cottage
# 3797  10118341     Fremont Lighthouse Mother-in-Law
# 3798   2614387   Everything Seattle in 0-3 miles, A
# 3799   7735100            Master bedroom in Fremont
# 3800   5482204                       Six room suite
# 3801   4524575        Comfortable Fremont Apartment
# 3802   8562314   Cozy Craftsman in Heart of Fremont
# 3803   9698202       Clean City House, Lots of Beds
# 3804   7178490  Cedar House Studio Suite in Fremont
# 3805   8054902     2 BR/1 BA Fremont Apt w/ parking
# 3806   5458027     Sunny Charm in Urban Cottage 2BD
# 3807   4940491     Roof Deck in Fremont/Wallingford
# 3808   1844791  Beautiful Craftsman - Fremont 3 Bed
# 3809   6120046        Lake Veiw Cottage  in Fremont
# 3810    262764                    Fremont Farmhouse
# 3811   8578490       Super Convenient Top Floor Apt
# 3812   3383329  OF THE TREE & CLOUDS. KID FRIENDLY!
# 3813   8101950   3BR Mountain View House in Seattle
# 3814   8902327    Portage Bay View!-One Bedroom Apt
# 3815  10267360    Private apartment view of Lake WA
# 3816   9604740    Amazing View with Modern Comfort!
# 3817  10208623            Large Lakefront Apartment
#
#                                                  street  \
# 0         Gilman Dr W, Seattle, WA 98119, United States
# 1     7th Avenue West, Seattle, WA 98119, United States
# 2     West Lee Street, Seattle, WA 98119, United States
# 3     8th Avenue West, Seattle, WA 98119, United States
# 4          14th Ave W, Seattle, WA 98119, United States
# 5     West Comstock Street, Seattle, WA 98119, Unite...
# 6     10th Avenue West, Seattle, WA 98119, United St...
# 7     West Wheeler Street, Seattle, WA 98119, United...
# 8     Queen Anne Avenue North, Seattle, WA 98109, Un...
# 9     7th Avenue West, Seattle, WA 98119, United States
# 10          1st Ave W, Seattle, WA 98119, United States
# 11    3rd Avenue West, Seattle, WA 98119, United States
# 12    West Howe Street, Seattle, WA 98119, United St...
# 13    West Prospect Street, Seattle, WA 98119, Unite...
# 14    7th Avenue West, Seattle, WA 98119, United States
# 15    12th Avenue West, Seattle, WA 98119, United St...
# 16    West Mercer Place, Seattle, WA 98119, United S...
# 17    12th Avenue West, Seattle, WA 98119, United St...
# 18    11th Avenue West, Seattle, WA 98119, United St...
# 19    1st Avenue West, Seattle, WA 98119, United States
# 20    West Olympic Place, Seattle, WA 98119, United ...
# 21    2nd Avenue West, Seattle, WA 98119, United States
# 22    1st Avenue West, Seattle, WA 98119, United States
# 23    West Galer Street, Seattle, WA 98119, United S...
# 24    10th Avenue West, Seattle, WA 98119, United St...
# 25    7th Avenue West, Seattle, WA 98119, United States
# 26    West McGraw Street, Seattle, WA 98119, United ...
# 27    West Wheeler Street, Seattle, WA 98119, United...
# 28    9th Avenue West, Seattle, WA 98119, United States
# 29    14th Avenue West, Seattle, WA 98119, United St...
# ...                                                 ...
# 3788  Woodland Park Avenue North, Seattle, WA 98103,...
# 3789  North 46th Street, Seattle, WA 98103, United S...
# 3790  North 35th Street, Seattle, WA 98103, United S...
# 3791  6th Avenue Northwest, Seattle, WA 98107, Unite...
# 3792  North 46th Street, Seattle, WA 98103, United S...
# 3793  Baker Avenue Northwest, Seattle, WA 98107, Uni...
# 3794  Northwest Bowdoin Place, Seattle, WA 98107, Un...
# 3795  Woodland Park Ave N, Seattle, WA 98103, United...
# 3796       NW 40th St, Seattle, WA 98107, United States
# 3797  Phinney Avenue North, Seattle, WA 98103, Unite...
# 3798  Midvale Avenue North, Seattle, WA 98103, Unite...
# 3799  Dayton Avenue North, Seattle, WA 98103, United...
# 3800  Linden Avenue North, Seattle, WA 98103, United...
# 3801  1st Avenue Northwest, Seattle, WA 98107, Unite...
# 3802  North 35th Street, Seattle, WA 98103, United S...
# 3803  Linden Avenue North, Seattle, WA 98103, United...
# 3804        N 44th st, Seattle, WA 98103, United States
# 3805  1st Avenue Northwest, Seattle, WA 98107, Unite...
# 3806  Greenwood Avenue North, Seattle, WA 98103, Uni...
# 3807  Stone Way North, Seattle, WA 98103, United States
# 3808  Dayton Avenue North, Seattle, WA 98103, United...
# 3809  Albion Place North, Seattle, WA 98103, United ...
# 3810     N Bowdoin Pl, Seattle, WA 98103, United States
# 3811  Whitman Avenue North, Seattle, WA 98103, Unite...
# 3812  Northwest 39th Street, Seattle, WA 98107, Unit...
# 3813  Northwest 48th Street, Seattle, WA 98107, Unit...
# 3814  Fuhrman Avenue East, Seattle, WA 98102, United...
# 3815  South Laurel Street, Seattle, WA 98178, United...
# 3816  43rd Avenue East, Seattle, WA 98112, United St...
# 3817  Westlake Avenue North, Seattle, WA 98109, Unit...
#
#      neighbourhood_cleansed neighbourhood_group_cleansed     city state  \
# 0           West Queen Anne                   Queen Anne  Seattle    WA
# 1           West Queen Anne                   Queen Anne  Seattle    WA
# 2           West Queen Anne                   Queen Anne  Seattle    WA
# 3           West Queen Anne                   Queen Anne  Seattle    WA
# 4           West Queen Anne                   Queen Anne  Seattle    WA
# 5           West Queen Anne                   Queen Anne  Seattle    WA
# 6           West Queen Anne                   Queen Anne  Seattle    WA
# 7           West Queen Anne                   Queen Anne  Seattle    WA
# 8           West Queen Anne                   Queen Anne  Seattle    WA
# 9           West Queen Anne                   Queen Anne  Seattle    WA
# 10          West Queen Anne                   Queen Anne  Seattle    WA
# 11          West Queen Anne                   Queen Anne  Seattle    WA
# 12          West Queen Anne                   Queen Anne  Seattle    WA
# 13          West Queen Anne                   Queen Anne  Seattle    WA
# 14          West Queen Anne                   Queen Anne  Seattle    WA
# 15          West Queen Anne                   Queen Anne  Seattle    WA
# 16          West Queen Anne                   Queen Anne  Seattle    WA
# 17          West Queen Anne                   Queen Anne  Seattle    WA
# 18          West Queen Anne                   Queen Anne  Seattle    WA
# 19          West Queen Anne                   Queen Anne  Seattle    WA
# 20          West Queen Anne                   Queen Anne  Seattle    WA
# 21          West Queen Anne                   Queen Anne  Seattle    WA
# 22          West Queen Anne                   Queen Anne  Seattle    WA
# 23          West Queen Anne                   Queen Anne  Seattle    WA
# 24          West Queen Anne                   Queen Anne  Seattle    WA
# 25          West Queen Anne                   Queen Anne  Seattle    WA
# 26          West Queen Anne                   Queen Anne  Seattle    WA
# 27          West Queen Anne                   Queen Anne  Seattle    WA
# 28          West Queen Anne                   Queen Anne  Seattle    WA
# 29          West Queen Anne                   Queen Anne  Seattle    WA
# ...                     ...                          ...      ...   ...
# 3788                Fremont          Other neighborhoods  Seattle    WA
# 3789                Fremont          Other neighborhoods  Seattle    WA
# 3790                Fremont          Other neighborhoods  Seattle    WA
# 3791                Fremont          Other neighborhoods  Seattle    WA
# 3792                Fremont          Other neighborhoods  Seattle    WA
# 3793                Fremont          Other neighborhoods  Seattle    WA
# 3794                Fremont          Other neighborhoods  Seattle    WA
# 3795                Fremont          Other neighborhoods  Seattle    WA
# 3796                Fremont          Other neighborhoods  Seattle    WA
# 3797                Fremont          Other neighborhoods  Seattle    WA
# 3798                Fremont          Other neighborhoods  Seattle    WA
# 3799                Fremont          Other neighborhoods  Seattle    WA
# 3800                Fremont          Other neighborhoods  Seattle    WA
# 3801                Fremont          Other neighborhoods  Seattle    WA
# 3802                Fremont          Other neighborhoods  Seattle    WA
# 3803                Fremont          Other neighborhoods  Seattle    WA
# 3804                Fremont          Other neighborhoods  Seattle    WA
# 3805                Fremont          Other neighborhoods  Seattle    WA
# 3806                Fremont          Other neighborhoods  Seattle    WA
# 3807                Fremont          Other neighborhoods  Seattle    WA
# 3808                Fremont          Other neighborhoods  Seattle    WA
# 3809                Fremont          Other neighborhoods  Seattle    WA
# 3810                Fremont          Other neighborhoods  Seattle    WA
# 3811                Fremont          Other neighborhoods  Seattle    WA
# 3812                Fremont          Other neighborhoods  Seattle    WA
# 3813                Fremont          Other neighborhoods  Seattle    WA
# 3814            Portage Bay                 Capitol Hill  Seattle    WA
# 3815          Rainier Beach               Rainier Valley  Seattle    WA
# 3816           Madison Park                 Capitol Hill  Seattle    WA
# 3817        East Queen Anne                   Queen Anne  Seattle    WA
#
#      zipcode   latitude   longitude    ...     review_scores_communication  \
# 0      98119  47.636289 -122.371025    ...                            10.0
# 1      98119  47.639123 -122.365666    ...                            10.0
# 2      98119  47.629724 -122.369483    ...                            10.0
# 3      98119  47.638473 -122.369279    ...                             NaN
# 4      98119  47.632918 -122.372471    ...                            10.0
# 5      98119  47.630525 -122.366174    ...                            10.0
# 6      98119  47.636605 -122.368519    ...                            10.0
# 7      98119  47.640161 -122.375856    ...                            10.0
# 8      98109  47.632410 -122.357216    ...                             9.0
# 9      98119  47.637492 -122.366889    ...                            10.0
# 10     98119  47.635482 -122.358478    ...                            10.0
# 11     98119  47.637214 -122.360046    ...                            10.0
# 12     98119  47.635546 -122.373171    ...                            10.0
# 13     98119  47.629507 -122.367629    ...                             9.0
# 14     98119  47.639203 -122.365863    ...                            10.0
# 15     98119  47.635650 -122.372893    ...                             8.0
# 16     98119  47.626200 -122.366602    ...                            10.0
# 17     98119  47.640646 -122.372406    ...                            10.0
# 18     98119  47.639776 -122.372235    ...                             NaN
# 19     98119  47.636025 -122.358694    ...                             9.0
# 20     98119  47.627940 -122.364959    ...                            10.0
# 21     98119  47.636374 -122.361033    ...                             9.0
# 22     98119  47.635632 -122.358881    ...                            10.0
# 23     98119  47.633394 -122.371920    ...                             NaN
# 24     98119  47.638517 -122.369581    ...                            10.0
# 25     98119  47.631397 -122.367767    ...                            10.0
# 26     98119  47.638752 -122.367973    ...                             NaN
# 27     98119  47.639266 -122.374726    ...                            10.0
# 28     98119  47.629907 -122.368948    ...                            10.0
# 29     98119  47.639816 -122.374338    ...                            10.0
# ...      ...        ...         ...    ...                             ...
# 3788   98103  47.656739 -122.344865    ...                            10.0
# 3789   98103  47.661171 -122.349923    ...                            10.0
# 3790   98103  47.649271 -122.347817    ...                            10.0
# 3791   98107  47.659149 -122.363466    ...                            10.0
# 3792   98103  47.663040 -122.348499    ...                             NaN
# 3793   98107  47.660056 -122.357683    ...                            10.0
# 3794   98107  47.654199 -122.359987    ...                            10.0
# 3795   98103  47.650124 -122.343283    ...                            10.0
# 3796   98107  47.656508 -122.360571    ...                            10.0
# 3797   98103  47.658976 -122.354915    ...                            10.0
# 3798   98103  47.655381 -122.343205    ...                            10.0
# 3799   98103  47.652902 -122.352110    ...                            10.0
# 3800   98103  47.663613 -122.349519    ...                             NaN
# 3801   98107  47.657078 -122.358795    ...                            10.0
# 3802   98103  47.650765 -122.347787    ...                             NaN
# 3803   98103  47.661131 -122.349238    ...                            10.0
# 3804   98103  47.660856 -122.352401    ...                            10.0
# 3805   98107  47.653158 -122.356285    ...                            10.0
# 3806   98103  47.656057 -122.354514    ...                            10.0
# 3807   98103  47.654304 -122.342720    ...                            10.0
# 3808   98103  47.662036 -122.350485    ...                            10.0
# 3809   98103  47.648689 -122.343915    ...                             9.0
# 3810   98103  47.654205 -122.352604    ...                            10.0
# 3811   98103  47.657898 -122.346692    ...                            10.0
# 3812   98107  47.654516 -122.358124    ...                            10.0
# 3813   98107  47.664295 -122.359170    ...                             8.0
# 3814   98102  47.649552 -122.318309    ...                            10.0
# 3815   98178  47.508453 -122.240607    ...                             NaN
# 3816   98112  47.632335 -122.275530    ...                             NaN
# 3817   98109  47.641186 -122.342085    ...                             NaN
#
#      review_scores_location review_scores_value  requires_license  \
# 0                       9.0                10.0             False
# 1                      10.0                10.0             False
# 2                      10.0                10.0             False
# 3                       NaN                 NaN             False
# 4                       9.0                 9.0             False
# 5                      10.0                10.0             False
# 6                      10.0                10.0             False
# 7                       9.0                10.0             False
# 8                      10.0                10.0             False
# 9                      10.0                 9.0             False
# 10                     10.0                10.0             False
# 11                     10.0                 9.0             False
# 12                     10.0                10.0             False
# 13                     10.0                10.0             False
# 14                     10.0                10.0             False
# 15                      8.0                 8.0             False
# 16                     10.0                 9.0             False
# 17                     10.0                10.0             False
# 18                      NaN                 NaN             False
# 19                      8.0                 8.0             False
# 20                     10.0                10.0             False
# 21                     10.0                 8.0             False
# 22                     10.0                10.0             False
# 23                      NaN                 NaN             False
# 24                     10.0                10.0             False
# 25                     10.0                10.0             False
# 26                      NaN                 NaN             False
# 27                      9.0                 9.0             False
# 28                     10.0                10.0             False
# 29                      9.0                 9.0             False
# ...                     ...                 ...               ...
# 3788                   10.0                10.0             False
# 3789                    9.0                 9.0             False
# 3790                   10.0                10.0             False
# 3791                   10.0                10.0             False
# 3792                    NaN                 NaN             False
# 3793                   10.0                10.0             False
# 3794                    9.0                 8.0             False
# 3795                   10.0                10.0             False
# 3796                   10.0                10.0             False
# 3797                   10.0                10.0             False
# 3798                   10.0                10.0             False
# 3799                   10.0                10.0             False
# 3800                    NaN                 NaN             False
# 3801                   10.0                10.0             False
# 3802                    NaN                 NaN             False
# 3803                   10.0                10.0             False
# 3804                   10.0                10.0             False
# 3805                   10.0                10.0             False
# 3806                   10.0                10.0             False
# 3807                   10.0                 9.0             False
# 3808                   10.0                 9.0             False
# 3809                    9.0                 8.0             False
# 3810                   10.0                 8.0             False
# 3811                   10.0                10.0             False
# 3812                    9.0                10.0             False
# 3813                   10.0                 8.0             False
# 3814                   10.0                10.0             False
# 3815                    NaN                 NaN             False
# 3816                    NaN                 NaN             False
# 3817                    NaN                 NaN             False
#
#       instant_bookable  cancellation_policy  require_guest_profile_picture  \
# 0                False             moderate                          False
# 1                False               strict                           True
# 2                False               strict                          False
# 3                False             flexible                          False
# 4                False               strict                          False
# 5                False               strict                          False
# 6                False             moderate                          False
# 7                False               strict                           True
# 8                False               strict                          False
# 9                False               strict                           True
# 10               False             moderate                           True
# 11               False               strict                          False
# 12               False             moderate                          False
# 13               False               strict                          False
# 14                True               strict                          False
# 15               False               strict                          False
# 16               False             moderate                          False
# 17                True             moderate                          False
# 18               False             flexible                          False
# 19               False             flexible                          False
# 20               False             flexible                          False
# 21               False             moderate                          False
# 22               False             flexible                          False
# 23               False             flexible                          False
# 24               False             moderate                          False
# 25               False               strict                          False
# 26               False             flexible                          False
# 27               False               strict                           True
# 28                True             moderate                          False
# 29               False               strict                          False
# ...                ...                  ...                            ...
# 3788             False               strict                          False
# 3789             False             flexible                          False
# 3790              True               strict                          False
# 3791             False             moderate                          False
# 3792             False             flexible                          False
# 3793              True               strict                          False
# 3794             False             flexible                          False
# 3795             False             flexible                          False
# 3796              True             moderate                          False
# 3797             False               strict                          False
# 3798             False               strict                          False
# 3799             False             moderate                          False
# 3800             False               strict                          False
# 3801             False             moderate                          False
# 3802             False             flexible                          False
# 3803             False             moderate                          False
# 3804             False               strict                          False
# 3805             False               strict                          False
# 3806             False             flexible                          False
# 3807             False               strict                          False
# 3808             False               strict                          False
# 3809             False               strict                          False
# 3810             False               strict                          False
# 3811             False             moderate                          False
# 3812              True             moderate                           True
# 3813             False               strict                          False
# 3814             False             moderate                          False
# 3815             False             moderate                          False
# 3816             False             moderate                          False
# 3817             False             flexible                          False
#
#      require_guest_phone_verification  reviews_per_month   host_id
# 0                               False               4.07    956883
# 1                                True               1.48   5177328
# 2                               False               1.15  16708587
# 3                               False                NaN   9851441
# 4                               False               0.89   1452570
# 5                               False               2.45    326758
# 6                               False               2.46   2497928
# 7                                True               4.73   4016632
# 8                               False               1.22   2166277
# 9                                True               1.55   5177328
# 10                              False               3.33    239585
# 11                              False               0.98   4606439
# 12                              False               0.92  19932967
# 13                              False               3.00  25899989
# 14                              False               2.65  22372266
# 15                              False               0.73   2983711
# 16                              False               4.55   9465817
# 17                              False               4.58  25417834
# 18                              False                NaN   6170760
# 19                              False               0.82  32713558
# 20                              False               1.00  14100483
# 21                              False               0.71  21401856
# 22                              False               0.86  46675077
# 23                              False                NaN  51860756
# 24                              False               0.18  33147763
# 25                              False               1.30  16708587
# 26                              False                NaN     68155
# 27                               True               4.38   4016632
# 28                              False               2.47   3792761
# 29                              False               0.33   6184895
# ...                               ...                ...       ...
# 3788                            False               3.39    398005
# 3789                            False               2.14  13771267
# 3790                            False               3.77   3752499
# 3791                            False               2.48  26392625
# 3792                            False                NaN  15784748
# 3793                            False               4.28  16727906
# 3794                            False               3.10  30049045
# 3795                            False               1.18  28007250
# 3796                            False               5.57   3023407
# 3797                            False               1.00   1237248
# 3798                            False               5.95   1123549
# 3799                            False               1.06   7227474
# 3800                            False                NaN  28432113
# 3801                            False               2.05  20853099
# 3802                            False                NaN  18774473
# 3803                            False               4.00   5325329
# 3804                            False               2.34    566102
# 3805                            False               3.95   4071088
# 3806                            False               0.24   6963318
# 3807                            False               0.78    466499
# 3808                            False               1.15   7964921
# 3809                            False               1.18  31752892
# 3810                            False               1.56   1379138
# 3811                            False               0.63  11847918
# 3812                             True               4.01   3443346
# 3813                            False               0.30  31148752
# 3814                            False               2.00  46566046
# 3815                            False                NaN  52791370
# 3816                            False                NaN  25522052
# 3817                            False                NaN  14703116
#
# [3818 rows x 50 columns]

# %% [markdown]
# ### Creating the "Hosts" dataframe and cleaning it

# %%
# Create new data with select columns for the AirBnB hosts
host_df = listing_host_df[["host_id","host_name","host_since","host_location","host_response_time","host_response_rate","host_acceptance_rate","host_is_superhost","host_neighbourhood","host_listings_count","host_has_profile_pic","host_identity_verified"]].copy()

# %%
# delete duplicates
host_df.drop_duplicates(keep="first",inplace=True)

# %%
# convert dates to datetime format
host_df["host_since"]=pd.to_datetime(host_df["host_since"])

# %%
# convert boolean columns to boolean
host_df["host_is_superhost"].replace(["t","f"],[True,False],inplace=True)
host_df["host_has_profile_pic"].replace(["t","f"],[True,False],inplace=True)
host_df["host_identity_verified"].replace(["t","f"],[True,False],inplace=True)

# %%
# converting the percentage columns from strings to percentages
# remove the percentage symbols from the columns with percentages
host_df["host_response_rate"]=host_df["host_response_rate"].replace({'\$': '', ',': '', '%':''}, regex=True)
host_df["host_acceptance_rate"]=host_df["host_acceptance_rate"].replace({'\$': '', ',': '', '%':''}, regex=True)
# convert the percentage columns to numbers
host_df["host_response_rate"] = pd.to_numeric(host_df["host_response_rate"])
host_df["host_acceptance_rate"] = pd.to_numeric(host_df["host_acceptance_rate"])
host_df
# Out:
#        host_id            host_name host_since  \
# 0       956883                Maija 2011-08-11
# 1      5177328               Andrea 2013-02-21
# 2     16708587                 Jill 2014-06-12
# 3      9851441                Emily 2013-11-06
# 4      1452570                Emily 2011-11-29
# 5       326758               Andrew 2010-12-25
# 6      2497928        Gary And Beth 2012-05-30
# 7      4016632            Jean-Marc 2012-10-30
# 8      2166277                Aliza 2012-04-18
# 10      239585         Ray & Eileen 2010-09-19
# 11     4606439                Nadia 2013-01-06
# 12    19932967        Pat & Roberta 2014-08-13
# 13    25899989                Ellie 2015-01-10
# 14    22372266                Sarah 2014-10-10
# 15     2983711                Paige 2012-07-18
# 16     9465817                Libby 2013-10-16
# 17    25417834   Markus And Melissa 2014-12-31
# 18     6170760                  Sam 2013-04-30
# 19    32713558                 Kary 2015-05-05
# 20    14100483                Annie 2014-04-09
# 21    21401856                 Nick 2014-09-16
# 22    46675077              Susanna 2015-10-16
# 23    51860756        Maggie & Alex 2015-12-20
# 24    33147763                Tracy 2015-05-11
# 26       68155                 Lori 2010-01-06
# 28     3792761             Kimberly 2012-10-07
# 29     6184895                 Lana 2013-05-01
# 31     5325329                Blair 2013-03-04
# 32    31037494               Silvia 2015-04-11
# 33    25906186             Vacation 2015-01-10
# ...        ...                  ...        ...
# 3775  45617021                 Kurt 2015-10-02
# 3776    781716                Andra 2011-07-05
# 3777  30030857                  Deb 2015-03-26
# 3780  36742703                 Joel 2015-06-25
# 3782  14012754                 Lara 2014-04-07
# 3783   7441000               Carrie 2013-07-12
# 3785  30609848              Melissa 2015-04-04
# 3788    398005               Trevor 2011-02-18
# 3790   3752499                Donna 2012-10-04
# 3791  26392625                Jason 2015-01-20
# 3792  15784748               Teresa 2014-05-20
# 3793  16727906                 Tory 2014-06-13
# 3794  30049045       Tim And Amanda 2015-03-26
# 3795  28007250             Brittney 2015-02-19
# 3796   3023407                  Nan 2012-07-23
# 3797   1237248                Elise 2011-10-02
# 3799   7227474                Roger 2013-07-01
# 3800  28432113  Chelsea Station Inn 2015-02-27
# 3801  20853099                Flora 2014-09-02
# 3802  18774473             Victoria 2014-07-23
# 3804    566102                  Eve 2011-05-07
# 3805   4071088                David 2012-11-05
# 3807    466499            Elizabeth 2011-03-27
# 3809  31752892                Megan 2015-04-22
# 3810   1379138               Rachel 2011-11-07
# 3811  11847918                 Ryan 2014-02-01
# 3814  46566046                 Glen 2015-10-14
# 3815  52791370             Virginia 2015-12-30
# 3816  25522052                Karen 2015-01-03
# 3817  14703116                  Gil 2014-04-25
#
#                                 host_location  host_response_time  \
# 0          Seattle, Washington, United States  within a few hours
# 1          Seattle, Washington, United States      within an hour
# 2          Seattle, Washington, United States  within a few hours
# 3          Seattle, Washington, United States                 NaN
# 4          Seattle, Washington, United States      within an hour
# 5          Seattle, Washington, United States                 NaN
# 6          Seattle, Washington, United States      within an hour
# 7          Seattle, Washington, United States      within an hour
# 8          Seattle, Washington, United States                 NaN
# 10         Seattle, Washington, United States  within a few hours
# 11         Seattle, Washington, United States  within a few hours
# 12         Seattle, Washington, United States      within an hour
# 13        Kirkland, Washington, United States      within an hour
# 14         Seattle, Washington, United States      within an hour
# 15         Seattle, Washington, United States  within a few hours
# 16         Seattle, Washington, United States      within an hour
# 17         Seattle, Washington, United States      within an hour
# 18         Seattle, Washington, United States                 NaN
# 19         Seattle, Washington, United States                 NaN
# 20        Quilcene, Washington, United States  within a few hours
# 21         Seattle, Washington, United States      within an hour
# 22         Seattle, Washington, United States        within a day
# 23         Seattle, Washington, United States                 NaN
# 24         Seattle, Washington, United States                 NaN
# 26         Seattle, Washington, United States  within a few hours
# 28         Seattle, Washington, United States      within an hour
# 29         Seattle, Washington, United States      within an hour
# 31         Seattle, Washington, United States  within a few hours
# 32         Seattle, Washington, United States        within a day
# 33                                         US      within an hour
# ...                                       ...                 ...
# 3775       Seattle, Washington, United States  within a few hours
# 3776       Seattle, Washington, United States                 NaN
# 3777       Seattle, Washington, United States  within a few hours
# 3780       Seattle, Washington, United States                 NaN
# 3782       Seattle, Washington, United States      within an hour
# 3783       Seattle, Washington, United States  within a few hours
# 3785       Seattle, Washington, United States        within a day
# 3788       Seattle, Washington, United States      within an hour
# 3790       Seattle, Washington, United States      within an hour
# 3791       Seattle, Washington, United States  within a few hours
# 3792       Seattle, Washington, United States      within an hour
# 3793       Seattle, Washington, United States      within an hour
# 3794       Seattle, Washington, United States  within a few hours
# 3795       Seattle, Washington, United States      within an hour
# 3796       Seattle, Washington, United States      within an hour
# 3797       Seattle, Washington, United States      within an hour
# 3799       Seattle, Washington, United States  a few days or more
# 3800       Seattle, Washington, United States                 NaN
# 3801       Seattle, Washington, United States  within a few hours
# 3802                                       US                 NaN
# 3804       Seattle, Washington, United States  within a few hours
# 3805       Seattle, Washington, United States      within an hour
# 3807  Arlington, Massachusetts, United States        within a day
# 3809       Seattle, Washington, United States        within a day
# 3810       Seattle, Washington, United States      within an hour
# 3811       Seattle, Washington, United States  within a few hours
# 3814       Seattle, Washington, United States      within an hour
# 3815                                       US                 NaN
# 3816        Tacoma, Washington, United States      within an hour
# 3817       Seattle, Washington, United States        within a day
#
#       host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                   96.0                 100.0             False
# 1                   98.0                 100.0              True
# 2                   67.0                 100.0             False
# 3                    NaN                   NaN             False
# 4                  100.0                   NaN             False
# 5                    NaN                   NaN             False
# 6                  100.0                 100.0              True
# 7                  100.0                 100.0              True
# 8                    NaN                 100.0             False
# 10                 100.0                 100.0              True
# 11                 100.0                 100.0             False
# 12                 100.0                 100.0              True
# 13                 100.0                 100.0             False
# 14                 100.0                 100.0             False
# 15                 100.0                 100.0             False
# 16                 100.0                 100.0             False
# 17                 100.0                 100.0              True
# 18                   NaN                   NaN             False
# 19                   NaN                   NaN             False
# 20                 100.0                 100.0             False
# 21                 100.0                 100.0             False
# 22                 100.0                 100.0             False
# 23                   NaN                   NaN             False
# 24                   NaN                   NaN             False
# 26                 100.0                 100.0             False
# 28                 100.0                 100.0             False
# 29                  71.0                 100.0             False
# 31                  97.0                 100.0             False
# 32                  60.0                 100.0             False
# 33                  71.0                 100.0             False
# ...                  ...                   ...               ...
# 3775                80.0                 100.0             False
# 3776                 NaN                   NaN              True
# 3777               100.0                 100.0             False
# 3780                 NaN                   NaN             False
# 3782               100.0                 100.0              True
# 3783               100.0                 100.0             False
# 3785               100.0                 100.0             False
# 3788               100.0                 100.0             False
# 3790               100.0                 100.0              True
# 3791               100.0                 100.0             False
# 3792               100.0                   NaN             False
# 3793               100.0                 100.0              True
# 3794                80.0                 100.0             False
# 3795               100.0                 100.0              True
# 3796               100.0                 100.0              True
# 3797               100.0                 100.0             False
# 3799                25.0                 100.0             False
# 3800                 NaN                   NaN             False
# 3801               100.0                 100.0              True
# 3802                 NaN                   NaN             False
# 3804               100.0                 100.0              True
# 3805               100.0                 100.0             False
# 3807               100.0                 100.0             False
# 3809               100.0                 100.0             False
# 3810               100.0                 100.0             False
# 3811               100.0                 100.0             False
# 3814               100.0                 100.0             False
# 3815                 NaN                   NaN             False
# 3816               100.0                   NaN             False
# 3817               100.0                   NaN             False
#
#      host_neighbourhood  host_listings_count host_has_profile_pic  \
# 0            Queen Anne                  3.0                 True
# 1            Queen Anne                  6.0                 True
# 2            Queen Anne                  2.0                 True
# 3            Queen Anne                  1.0                 True
# 4            Queen Anne                  2.0                 True
# 5            Queen Anne                  1.0                 True
# 6            Queen Anne                  1.0                 True
# 7            Queen Anne                  5.0                 True
# 8            Queen Anne                  1.0                 True
# 10           Queen Anne                  1.0                 True
# 11           Queen Anne                  1.0                 True
# 12                  NaN                  1.0                 True
# 13           Queen Anne                  1.0                 True
# 14           Queen Anne                  1.0                 True
# 15                  NaN                  1.0                 True
# 16           Queen Anne                  1.0                 True
# 17           Queen Anne                  1.0                 True
# 18           Queen Anne                  1.0                 True
# 19           Queen Anne                  1.0                 True
# 20                  NaN                  1.0                 True
# 21           Queen Anne                  1.0                 True
# 22           Queen Anne                  1.0                 True
# 23           Queen Anne                  1.0                 True
# 24           Queen Anne                  1.0                 True
# 26           Queen Anne                  1.0                 True
# 28           Queen Anne                  5.0                 True
# 29           Queen Anne                  1.0                 True
# 31           Queen Anne                  9.0                 True
# 32           Queen Anne                  1.0                 True
# 33           Queen Anne                  1.0                 True
# ...                 ...                  ...                  ...
# 3775            Fremont                  1.0                 True
# 3776            Fremont                  1.0                 True
# 3777            Fremont                  1.0                 True
# 3780            Fremont                  1.0                 True
# 3782            Fremont                  1.0                 True
# 3783            Fremont                  1.0                 True
# 3785            Fremont                  1.0                 True
# 3788            Fremont                  1.0                 True
# 3790            Fremont                  1.0                 True
# 3791            Fremont                  1.0                 True
# 3792            Fremont                  1.0                 True
# 3793            Fremont                  1.0                 True
# 3794            Fremont                  1.0                 True
# 3795                NaN                  1.0                 True
# 3796            Fremont                  1.0                 True
# 3797            Fremont                  1.0                 True
# 3799            Fremont                  1.0                 True
# 3800            Fremont                  1.0                 True
# 3801            Fremont                  1.0                 True
# 3802                NaN                  1.0                 True
# 3804            Fremont                  1.0                 True
# 3805            Fremont                  1.0                 True
# 3807        Wallingford                  1.0                 True
# 3809            Fremont                  1.0                 True
# 3810            Fremont                  1.0                 True
# 3811            Fremont                  1.0                 True
# 3814        Portage Bay                  1.0                 True
# 3815                NaN                  1.0                 True
# 3816                NaN                  1.0                 True
# 3817         Queen Anne                  1.0                 True
#
#      host_identity_verified
# 0                      True
# 1                      True
# 2                      True
# 3                      True
# 4                      True
# 5                      True
# 6                      True
# 7                      True
# 8                      True
# 10                     True
# 11                     True
# 12                     True
# 13                     True
# 14                     True
# 15                    False
# 16                     True
# 17                     True
# 18                     True
# 19                     True
# 20                     True
# 21                    False
# 22                    False
# 23                    False
# 24                    False
# 26                     True
# 28                     True
# 29                     True
# 31                     True
# 32                     True
# 33                     True
# ...                     ...
# 3775                   True
# 3776                   True
# 3777                   True
# 3780                  False
# 3782                   True
# 3783                   True
# 3785                  False
# 3788                   True
# 3790                   True
# 3791                   True
# 3792                  False
# 3793                   True
# 3794                   True
# 3795                   True
# 3796                   True
# 3797                   True
# 3799                   True
# 3800                  False
# 3801                   True
# 3802                  False
# 3804                   True
# 3805                   True
# 3807                  False
# 3809                   True
# 3810                   True
# 3811                   True
# 3814                   True
# 3815                  False
# 3816                   True
# 3817                   True
#
# [2751 rows x 12 columns]

# %% [markdown]
# ### Creating the "Availability" dataframe and cleaning it

# %%
# Store CSV to DataFrame
availability_file = "Resources/calendar.csv"
availability_df = pd.read_csv(availability_file,encoding="utf8")

# %%
# change column "date" to something that SQL doesn't already recognize
availability_df.rename(index=str,columns={"date":"available_date"},inplace=True)
# convert column to datetime
availability_df["available_date"]=pd.to_datetime(availability_df["available_date"])

# %%
# convert boolean columns to boolean
availability_df["available"].replace(["t","f"], [True,False], inplace=True)

# %%
# remove dollar sign
availability_df["price"] = availability_df["price"].replace({'\$': '', ',': ''}, regex=True)
# convert the price column to numeric values instead of strings
availability_df["price"] = pd.to_numeric(availability_df["price"])
availability_df.head()
# Out:
#    listing_id available_date  available  price
# 0      241032     2016-01-04       True   85.0
# 1      241032     2016-01-05       True   85.0
# 2      241032     2016-01-06      False    NaN
# 3      241032     2016-01-07      False    NaN
# 4      241032     2016-01-08      False    NaN

# %% [markdown]
# ### Creating the "Reviews" dataframe and cleaning it

# %%
# Store CSV to DataFrame
reviews_file = "Resources/reviews.csv"
reviews_df = pd.read_csv(reviews_file,encoding="utf8")

# %%
# change column "date/id" to something that SQL doesn't already recognize
reviews_df.rename(index=str,columns={"date":"review_date"},inplace=True)
reviews_df.rename(columns={"id":"review_id"}, inplace=True)

# %%
# Create new data with select columns for the AirBnB listings
review_df = reviews_df[['review_id', "listing_id", "review_date", "reviewer_id", "reviewer_name", "comments"]].copy()

# %%
# convert dates to datetime
review_df["review_date"] = pd.to_datetime(review_df["review_date"])
review_df.head()
# Out:
#    review_id  listing_id review_date  reviewer_id reviewer_name  \
# 0   38917982     7202016  2015-07-19     28943674        Bianca
# 1   39087409     7202016  2015-07-20     32440555         Frank
# 2   39820030     7202016  2015-07-26     37722850           Ian
# 3   40813543     7202016  2015-08-02     33671805        George
# 4   41986501     7202016  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %% [markdown]
# ### SQL

# %%
# establish the MySQL database connection and create the engine
rds_connection_string = "root:<INSERT PASSWORD>@127.0.0.1/seattle_airbnb_db"
engine = create_engine(f"mysql+pymysql://{rds_connection_string}?charset=utf8", encoding = "utf8")

# %%
# check tablenames in the MySQL database
engine.table_names()
# Out:
# ['airbnb_hosts', 'listings', 'property_availability', 'property_reviews']

# %%
# add the hosts dataframe to MySQL
host_df.to_sql(name="airbnb_hosts",con=engine,if_exists="append",index=False,chunksize=2000)

# %%
# add the listings dataframe to MySQL
listing_df.to_sql(name="listings",con=engine,if_exists="append",index=False,chunksize=200)

# %%
# add the property availability dataframe to MySQL
availability_df.to_sql(name="property_availability",con=engine,if_exists="append",index=False,chunksize=2000)

# %%
# add the property reviews dataframe to MySQL
reviews_df.to_sql(name="property_reviews",con=engine,if_exists="append",index=False,chunksize=2000)
